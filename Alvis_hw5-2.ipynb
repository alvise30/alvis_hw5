# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq
from scipy import fftpack
import scikits.audiolab as audio
from scipy.fftpack import fft, fftfreq
from __future__ import division
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fftpack', 'fft', 'e']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
input_signal, sampling_rate, enc = audio.wavread("voice.wav")
print (input_signal[0:10]), sampling_rate, enc
# Out:
# [  0.00000000e+00   0.00000000e+00   3.05175781e-05  -6.10351562e-05
#    6.10351562e-05   3.05175781e-05  -2.74658203e-04   7.62939453e-04
#   -2.28881836e-03  -7.72094727e-03] 48000 pcm16

# %%
t_arr = arange(0, len(input_signal)/float(sampling_rate), 1/float(sampling_rate))
print len(time_array), len(input_signal)
# Out:
# 96000 96000

# %%
n_points  = len(input_signal)
plot(time_array, input_signal)
xlabel("Tiempo(s)", fontsize=20)
ylabel("Amplitud", fontsize=20)

# %%
fft_input_signal = fft(input_signal) / n_points 
freq = fftfreq(n_points, 1) 
plt.plot(freq,np.abs(fft_input_signal))
plt.xlim(-0.05,0.05)
# Out:
# (-0.05, 0.05)

# %%
half_n = np.ceil(n_points/2.0)
fft_input_signal_half = (2.0) * fft_input_signal[:half_n]
freq_half = freq[:half_n]

# %%
scatter(freq_half, log10(np.absolute(fft_input_signal_half)**2))

# %%
clean_f = ifft(fft_input_signal*n_points) 
plot(clean_f)

# %%
fft_input_signal_wn = fft_input_signal / np.absolute(fft_input_signal)
clean_wn = ifft(fft_input_signal_white_noise) 
plot(clean_wn)
output_file = audio.Sndfile("whitenoise.wav", 'w', audio.Format('wav'), 1, sampling_rate)
output_file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-df8cae284e12> in <module>()
#       3 plot(clean_wn)
#       4 output_file = audio.Sndfile("whitenoise.wav", 'w', audio.Format('wav'), 1, sampling_rate)
# ----> 5 output_file.write_frames(clean_wn)
#       6 output_file.close()
#
# /usr/local/lib/python2.7/dist-packages/scikits.audiolab-0.11.0-py2.7-linux-i686.egg/scikits/audiolab/pysndfile/_sndfile.so in scikits.audiolab.pysndfile._sndfile.Sndfile.write_frames (scikits/audiolab/pysndfile/_sndfile.c:6813)()
#
# TypeError: not all arguments converted during string formatting

# %%
half_n = np.ceil(n_points/2.0)
fft_input_signal_hwn = (2.0) * fft_input_signal_wn[:half_n]
freq_half_norm = freq[:half_n]
scatter(freq_half_norm, log10(np.absolute(fft_input_signal_hwn)**2))

# %%
fft_input_signal_pn = fft_input_signal_wn[1:] / freq[1:]
clean_pn = ifft(fft_input_signal_pn) 
plot(clean_pn)
output_file = audio.Sndfile("pinknoise.wav", 'w', audio.Format('wav'), 1, sampling_rate)
output_file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-e029e9c60309> in <module>()
#       3 plot(clean_pn)
#       4 output_file = audio.Sndfile("pinknoise.wav", 'w', audio.Format('wav'), 1, sampling_rate)
# ----> 5 output_file.write_frames(clean_pn)
#       6 output_file.close()
#
# /usr/local/lib/python2.7/dist-packages/scikits.audiolab-0.11.0-py2.7-linux-i686.egg/scikits/audiolab/pysndfile/_sndfile.so in scikits.audiolab.pysndfile._sndfile.Sndfile.write_frames (scikits/audiolab/pysndfile/_sndfile.c:6813)()
#
# TypeError: not all arguments converted during string formatting

# %%
half_n = np.ceil(n_points/2.0)
fft_input_signal_half_pink_noise = (2.0) * fft_input_signal_pink_noise[:half_n]
freq_half_norm = freq[:half_n]
scatter(freq_half_norm, log10(np.absolute(fft_input_signal_half_pink_noise)**2))

# %%
plot(clean_white_noise)
plot(clean_pink_noise)
